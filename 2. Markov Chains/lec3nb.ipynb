# %% [markdown]
# # Jupyter notebook w/ R code for Topic 2

# %%
getwd()
# Out:
# [1] "/Users/josenino-mora/Documents/Docum2/Teaching/IOuc3m/2023_24/SP"

# %%
setwd('/Users/josenino-mora/Documents/Docum2/Teaching/IOuc3m/2023_24/SP/Lec3')

# %%
source("utilities.R");
# Out:
# plot without title

# %%
P <- matrix(c(0.51, 0.49, 0.49, 0.51), nrow=2, byrow=T)

# %%
P
# Out:
#      [,1] [,2]
# [1,] 0.51 0.49
# [2,] 0.49 0.51

# %%
P %*% P
# Out:
#      [,1]   [,2]
# [1,] 0.5002 0.4998
# [2,] 0.4998 0.5002

# %%
matrixpower(P, 3)
# Out:
#      [,1]     [,2]
# [1,] 0.500004 0.499996
# [2,] 0.499996 0.500004

# %%
alpha = matrix(c(1, 0), nrow=1, byrow=T)
markov(alpha, P, 10)
states = matrix(c(0, 1), nrow=1, byrow=T)
markov(alpha, P, 10, states)
# Out:
#  [1] 1 2 1 2 1 1 2 2 1 1 2
#  [1] 0 1 0 1 1 0 1 0 1 0 0

# %%
P <- matrix(c(0.175, 0.825, 0.526, 0.474), nrow=2, byrow=T)

# %%
P
# Out:
#      [,1]  [,2]
# [1,] 0.175 0.825
# [2,] 0.526 0.474

# %%
P <- matrix(c(0.2, 0.6, 0.2, 0.1, 0.8, 0.1, 0.1, 0.6, 0.3), nrow=3, byrow=T)

# %%
P
# Out:
#      [,1] [,2] [,3]
# [1,] 0.2  0.6  0.2
# [2,] 0.1  0.8  0.1
# [3,] 0.1  0.6  0.3

# %%
alpha <- matrix(c(0.5, 0.5, 0), nrow=1, byrow=T)

# %%
alpha
# Out:
#      [,1] [,2] [,3]
# [1,] 0.5  0.5  0

# %%
alpha %*% matrixpower(P, 2)
# Out:
#      [,1]  [,2] [,3]
# [1,] 0.115 0.74 0.145

# %%
matrixpower(P, 2)
# Out:
#      [,1] [,2] [,3]
# [1,] 0.12 0.72 0.16
# [2,] 0.11 0.76 0.13
# [3,] 0.11 0.72 0.17

# %%
P <- matrix(c(0.0, 0.5, 0.5, 0.0,
              0.5, 0.0, 0.5, 0.0,
              0.4, 0.0, 0.0, 0.6,
              0.0, 0.2, 0.6, 0.2), nrow=4, byrow=T)

# %%
P
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 0.0  0.5  0.5  0.0
# [2,] 0.5  0.0  0.5  0.0
# [3,] 0.4  0.0  0.0  0.6
# [4,] 0.0  0.2  0.6  0.2

# %%
matrixpower(P, 2)
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 0.45 0.00 0.25 0.30
# [2,] 0.20 0.25 0.25 0.30
# [3,] 0.00 0.32 0.56 0.12
# [4,] 0.34 0.04 0.22 0.40

# %%
alpha <- matrix(c(0.25, 0.25, 0.25, 0.25), nrow=1, byrow=T)

# %%
alpha
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 0.25 0.25 0.25 0.25

# %%
alpha %*% matrixpower(P, 3)
# Out:
#      [,1]    [,2]    [,3]  [,4]
# [1,] 0.20425 0.17975 0.368 0.248

# %%
matrixpower(P, 34)
# Out:
#      [,1]      [,2]      [,3]      [,4]
# [1,] 0.2222222 0.1637427 0.3508772 0.2631579
# [2,] 0.2222222 0.1637427 0.3508772 0.2631579
# [3,] 0.2222222 0.1637427 0.3508772 0.2631579
# [4,] 0.2222222 0.1637427 0.3508772 0.2631579
